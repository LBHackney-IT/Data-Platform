# %%
import sys
from awsglue.utils import getResolvedOptions
import pyspark.sql.functions as F
from pyspark import SparkContext
from awsglue.context import GlueContext
from awsglue.dynamicframe import DynamicFrame
from awsglue.job import Job
from pyspark.sql.functions import col, max
from pyspark.sql.types import StringType, IntegerType, BooleanType, DateType, FloatType, TimestampType, LongType, DoubleType, MapType, ArrayType
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>Current session?</th></tr><tr><td>0</td><td>None</td><td>pyspark</td><td>idle</td><td></td><td></td><td>✔</td></tr></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# from helpers import get_glue_env_var, get_latest_partitions, PARTITION_KEYS
# from helpers import get_glue_env_var, PARTITION_KEYS

glueContext = GlueContext(SparkContext.getOrCreate())
job = Job(glueContext)

PARTITION_KEYS = ["import_year", "import_month", "import_day", "import_date"]

def get_latest_partitions(dfa):
   dfa = dfa.where(col('import_year') == dfa.select(max('import_year')).first()[0])
   dfa = dfa.where(col('import_month') == dfa.select(max('import_month')).first()[0])
   dfa = dfa.where(col('import_day') == dfa.select(max('import_day')).first()[0])
   return dfa
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
columnsDictionary_df = spark.read.option("multiline", "true").json("s3://dataplatform-stg-refined-zone/TEMP/tascomiDict2.json")
# df = spark.read.json("s3://dataplatform-stg-refined-zone/TEMP/tascomiDict.json")
# df.first()[0]["appeal_decision"]
# df.show()
# columnsDictionary_df.printSchema()
# columnsDictionary_df.select("integer").show(truncate=False)
columnsDictionary_df.select("integer").printSchema()
# columnsDictionary_df.select("integer.appeal_decision").printSchema()
# columnsDictionary_df.select("timestamp.applications").printSchema()
# columnsDictionary_df.select("timestamp.appeal_decision").show(truncate=False)
# columnsDictionary_df.select("timestamp.contacts").show(truncate=False)
# columnsDictionary_df.select("integer.appeal_decision").show(truncate=False)
string_type = "float"
string_table = "contacts"
# str_list = columnsDictionary_df.select(string_type+'.'+string_table).first()[0].split(',')
# str_list = list(filter(None, str_list))
# str_list
columnsDictionary_df.first()["integer"]
columnsDictionary_df.select('long').show(truncate=False)
# listColumns = columnsDictionary_df.columns
# if "timestamp" in listColumns:
#     columnsDictionary_df.printSchema()
    

"contacts:" in columnsDictionary_df.select("float").schema.simpleString()

# columnsDictionary_df.select("integer.applications").show()

# df3.show()
# columnsDictionary_df.select("timestamp").show(truncate=False)

# df.first()
# df.filter("columns_type = 'timestamp'").select("columns_per_table").collect()[0][0]["appeal_decision"]
# df.filter("columns_type = 'timestamp'").select("columns_per_table").first()[0]["appeal_decision"]
# columnsDictionary_df.filter("data_type = 'integer'").first()["applications"].split(',')
# columnsDictionary_df["integer"].first()["applications"].split(',')
# columnsDictionary_df.filter("columns_type = 'integer'").first()["columns_per_table"]

# df.collect()[1][0]["appeal_decision"]
# columnsDictionary_df["integer"].show()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# root
#  |-- integer: struct (nullable = true)
#  |    |-- appeal_decision: string (nullable = true)
#  |    |-- appeal_status: string (nullable = true)
#  |    |-- appeal_types: string (nullable = true)
#  |    |-- applications: string (nullable = true)
#  |    |-- breach_types: string (nullable = true)
#  |    |-- committees: string (nullable = true)
#  |    |-- communication_templates: string (nullable = true)
#  |    |-- communication_types: string (nullable = true)
#  |    |-- communications: string (nullable = true)
#  |    |-- contact_types: string (nullable = true)
#  |    |-- contacts: string (nullable = true)
#  |    |-- decision_levels: string (nullable = true)
#  |    |-- decision_types: string (nullable = true)
#  |    |-- document_types: string (nullable = true)
#  |    |-- emails: string (nullable = true)
#  |    |-- enforcements: string (nullable = true)
# ...

# %%
# jsonString="""{"Zipcode":704,"ZipCodeType":"STANDARD, STANDARD2, STANDARD3","City":"PARC PARQUE","State":"PR"}"""
jsonString = spark.read.text("s3://dataplatform-stg-refined-zone/TEMP/tascomiDict.json")
# jsonString = SparkContext.getOrCreate().textFile('s3://dataplatform-stg-refined-zone/TEMP/tascomiDict.json')
jsonString.show(truncate=False)
# df=spark.createDataFrame([(1, jsonString)],["id","value"])
# df.show(truncate=False)

# #Convert JSON string column to Map type
# from pyspark.sql.types import MapType,StringType
# from pyspark.sql.functions import from_json
# df2=df.withColumn("value",from_json(df.value,MapType(StringType(),StringType())))
# df2.printSchema()
# df2.show(truncate=False)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ...

# %%
map2 = df2.first()[1]
map2['Zipcode']
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# '704'

# %%
# jsonString="""{"timestampColumnsMap":{"applications":"advertisement_from,advertisement_to,agricultural_holding_involved_owner_notified","contacts":"ceased_date,last_updated,submit_date"}, "integerColumnsMap":{"applications":"admin_officer_id,agent_id,agricultural_holding_involved_owner_details", "contacts":"company_type_id,contact_type_id,creation_user_id,dtf_location_id"}}"""
jsonString = '[{"timestamp":{"applications": "submit_date,advertisement_to","contacts": "ceased_date,last_updated, submit_date"}, "long":{"applications": "id","contacts": "id"}}]'
df=spark.createDataFrame([(1, jsonString)],["id","value"])

#Convert JSON string column to Map type
from pyspark.sql.types import MapType,StringType, StructType
from pyspark.sql.functions import from_json
df3=df.withColumn("value",from_json(df.value,StructType()))
df3.show(truncate=False)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +---+-----+
# |id |value|
# +---+-----+
# |1  |[]   |
# +---+-----+
#
# /usr/local/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/local/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
map3 = df3.first()[1]
df4 = spark.createDataFrame([("timestampColumnsMap", map3['timestampColumnsMap']), ("integerColumnsMap", map3['integerColumnsMap'])],["id","value"])
# timestampColumnsMap = map3['timestampColumnsMap']
df4.show()
df4=df4.withColumn("value",from_json(df4.value,MapType(StringType(),StringType())))
df4.show()
# timestampColumnsMap2 = from_json(timestampColumnsMap,MapType(StringType(),StringType()))
# timestampColumnsMap2
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------------------+--------------------+
# |                 id|               value|
# +-------------------+--------------------+
# |timestampColumnsMap|{"applications":"...|
# |  integerColumnsMap|{"applications":"...|
# +-------------------+--------------------+
#
# +-------------------+--------------------+
# |                 id|               value|
# +-------------------+--------------------+
# |timestampColumnsMap|[applications -> ...|
# |  integerColumnsMap|[applications -> ...|
# +-------------------+--------------------+

# %%
timestampColumnsMap = df4.filter("id = 'timestampColumnsMap'").first()[1]
integerColumnsMap = df4.filter("id = 'integerColumnsMap'").first()[1]
timestampColumnsMap['applications'].split(',')
integerColumnsMap['contacts'].split(',')
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ['company_type_id', 'contact_type_id', 'creation_user_id', 'dtf_location_id']

# %%
for colName in columnMap[tableName]:
        print ("converting " + colName + " to date")
        df = df.withColumn(colName ,col(colName).cast(DateType()))

# %%
tableList = ["applications", "contacts"]
# tableList = ["public_comments"]
databaseName = "dataplatform-stg-tascomi-raw-zone"
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# Lazy approach with lists of column names to recast, common to all tables. For each table we test the presence of all the columns

timeStampColumns = ["last_updated","date_of_change", "submit_date", "ceased_date"]
dateColumns = ["completed_date", "appeal_start_date", "final_comments_due_date", "final_comments_sent_date"]
booleanColumns = ["is_default", "statutory_consultee", "show_on_portal"]
intColumns = []

def castIdColumnL(df):
    df = df.withColumn("id" ,col("id").cast(IntegerType()))
    return df
    
def castTimestampColumnsL(df):
    for colName in timeStampColumns:
        if (colName in source_df.columns):
            print ("converting " + colName + " to timestamp")
            df = df.withColumn(colName ,col(colName).cast(TimestampType()))
    return df

def castDateColumnsL(df):
    for colName in dateColumns:
        if (colName in source_df.columns):
            print ("converting " + colName + " to date")
            df = df.withColumn(colName ,col(colName).cast(DateType()))
    return df


def castBooleanColumnsL(df):
    for colName in booleanColumns:
        if (colName in source_df.columns):
            print ("converting " + colName  + " to boolean")
            df = df.withColumn(colName ,col(colName).cast(BooleanType()))
    return df


# source_df = castIdColumn(df=source_df)
# source_df = castTimestampColumns(df=source_df)
# source_df = castDateColumns(df=source_df)
# source_df = castBooleanColumns(df=source_df)


# source_df.printSchema()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# More serious approach with a dictionary (Map) showing for each table the exact list of column names to recast

# Format of the Map: "tascomiTableName":["timestampColumn1", "timestampColumn2", "timestampColumn3"]
# timestampColumnsMap = {\
#     "applications": ["last_updated"],\
#     "contacts": ["last_updated", "submit_date", "ceased_date"],\
#     "emails": ["last_updated", "submit_date", "ceased_date"],\
#     "enforcements": ["last_updated", "submit_date", "ceased_date"],\
#     "fees": ["last_updated", "submit_date", "ceased_date"],\
#     "public_comments": [...],\
#     "communications": [...],\
#     "fee_payments": [...],\
#     "appeal_decision": [...],\
#     "appeal_status": [...],\
#     "appeal_types": [...],\
#     "breach_types": [...],\
#     "committees": [...],\
#     "communication_templates": [...],\
#     "communication_types": [...],\
#     "contact_types": [...],\
#     "decision_levels": [...],\
#     "decision_types": [...],\
#     "document_types": [...],\
#     "fee_types": [...],\
#     "ps_development_codes": [...],\
#     "public_consultations": [...]}

timestampColumnsMap = {\
    "applications": ["advertisement_from","advertisement_to","agricultural_holding_involved_owner_notified","agricultural_holding_involved_signed_on","application_declaration_signed_on","beneficial_occupation_date","brought_into_use_date_20_march_2013_or_later","ceased_date","certificate_a_signed_on","certificate_b_owner_notified","certificate_b_signed_on","certificate_c_owner_notified","certificate_c_publicity_date","certificate_c_signed_on","certificate_d_publicity_date","certificate_d_signed_on","certificate_of_compliance_a_signed_on","certificate_of_compliance_b_owner_notified","certificate_of_compliance_b_signed_on","certificate_of_compliance_c_owner_notified","certificate_of_compliance_c_publicity_date","certificate_of_compliance_c_signed_on","commencement_date","committee_actual_date","committee_date","committee_proposed_date","completion_date","date_decision_taken","date_of_advice","date_of_decision_5rm","date_of_deed_of_variation_if_any","date_of_s106_agreement","decision_expiry_date","decision_issued_date","development_already_completed_date","development_already_started_date","documents_to_legal_date","end_of_previous_use","expiry_date","expiry_of_temporary_consent_use_operations","extension_of_time_due_date","ian_deadline_date","iii_date_proposed_demolition_area_built","implementation_date","intial_vetting_date","last_in_use_date","last_in_use_date_if_not_20_march_2013","last_updated","last_use_as_arcade_casino","legal_agreement_date","legal_draft_received_date","legal_services_instructed_date","non_agricultural_holding_signed_on","original_decision_date","planned_commencement","planned_completion","planning_portal_submit_date","planning_reference_date","ppa_decision_due_date","received_date","record_allocated_date","reference_condition_date","referral_date","referral_returned_date","registration_date","returned_to_admin_date","s73_reference_if_any_date","statutory_declaration_received_date","submit_date","use_works_activity_date","valid_date","work_completed_date","work_started_date"],\
    "contacts": ["ceased_date", "last_updated", "submit_date"],\
    "emails": ["ceased_date","email_date","last_updated","submit_date"],\
    "enforcements": ["ceased_date","complainant_acknowledged_date","complainant_correspondence_date","complaint_received","complaint_received_date","complaint_registered","date_file_closed","investigation_date","last_updated","resolution_date","site_visit_target_date","submit_date","target_for_closure"],\
    "fees": ["ceased_date","last_updated","submit_date"],\
    "public_comments": ["ceased_date","last_updated","submit_date"],\
    "communications": ["ceased_date","completed_date","emailed_date","last_updated","printed_date","submit_date"],\
    "fee_payments": ["ceased_date","last_updated","payment_date","submit_date"],\
    "appeal_decision": ["ceased_date","last_updated","submit_date"],\
    "appeal_status": ["ceased_date","last_updated","submit_date"],\
    "appeal_types": ["ceased_date","last_updated","submit_date"],\
    "breach_types": ["ceased_date","last_updated","submit_date"],\
    "committees": ["actual_date","appeal_decision_from_date","appeal_decision_to_date","appeal_received_from_date","appeal_received_to_date","ceased_date","delegated_decision_from_date","delegated_decision_to_date","last_updated","proposed_date","submit_date"],\
    "communication_templates": ["ceased_date","last_updated","submit_date"],\
    "communication_types": ["ceased_date","last_updated","submit_date"],\
    "contact_types": ["ceased_date","last_updated","submit_date"],\
    "decision_levels": ["ceased_date","last_updated","submit_date"],\
    "decision_types": ["ceased_date","last_updated","submit_date"],\
    "document_types": ["ceased_date","last_updated","submit_date"],\
    "fee_types": ["ceased_date","last_updated","submit_date"],\
    "ps_development_codes": ["ceased_date","last_updated","submit_date"],\
    "public_consultations": ["ceased_date","last_updated","submit_date"]}

integerColumnsMap = {\
    "applications": ["admin_officer_id","agent_id","agricultural_holding_involved_owner_details","agricultural_land_use_months","agricultural_land_use_years","applicant_id","application_source_id","application_stage","application_type_id","approved_units","breeam_level_id","breeam_status_id","car_difference","car_total_existing","car_total_proposed","certificate_b_owner_details","certificate_c_owner_details","certificate_of_compliance_b_owner_details","certificate_of_compliance_c_owner_details","community_id","creation_user_id","cycle_difference","cycle_total_existing","cycle_total_proposed","decision_expiry_months","decision_expiry_years","decision_level_id","decision_monitoring_standard_phrase_id","decision_officer_id","decision_type_id","decision_user_team_id","disability_difference","disability_total_existing","disability_total_proposed","dtf_location_id","eia_id","existing_employees_full_time","existing_employees_full_time_equivalent","existing_employees_part_time","external_referee","external_referee_id","felled_trees","id","ii_volume_to_be_demolished","i_total_building_volume","last_updated_by","legal_agreement_obligation_type_id","lgv_difference","lgv_total_existing","lgv_total_proposed","motorcycles_difference","motorcycles_total_existing","motorcycles_total_proposed","net_increase_in_dwellings","net_increase_in_dwellings_4bcd","net_increase_in_dwellings_4scd","officer_id","original_application_reference","original_application_type","other_difference","other_owner_details","other_total_existing","other_total_proposed","overturn_reason_id","parish_id","proposed_employees_full_time","proposed_employees_full_time_equivalent","proposed_employees_part_time","pruned_trees","ps_development_code_id","referral_reason_id","requested_committee_meeting_id","residential_development_type_id","service_centre_id","settlement_group_id","site_visit_other_contact","surface_site_owner","temporary_consent_months","temporary_consent_years","tree_location","user_team_id","validation_officer_id","ward_id"],\
    "contacts": ["company_type_id","contact_type_id","creation_user_id","dtf_location_id","id","last_updated_by","title_id"],\
    "emails": ["appeal_id","application_id","asset_constraint_id","communication_file_id","creation_user_id","enforcement_id","id","last_updated_by","legal_agreement_id","mandrill_status_check_count","preapplication_id"],\
    "enforcements": ["admin_officer_id","case_officer_id","community_id","complainant_details","complainant_id","complaint_location","complaint_location_id","complaint_source","complaint_source_id","creation_user_id","enforcement_case_status_id","enforcement_outcome_type_id","enforcement_protocol_id","id","last_updated_by","offender_details","offender_id","offender_interest_id","priority_status_id","reason_for_file_closure_id","target_for_closure_weeks","user_team_id","ward_id"],\
    "fees": ["appeal_id","application_id","applied_fee_reason_id","creation_user_id","enforcement_id","exemption_reason_id","fee_type_2_id","fee_type_3_id","fee_type_id","id","last_updated_by","payment_method_id","preapplication_id","proposed_no_of_dwellings"],\
    "public_comments": ["application_id","creation_user_id","id","last_updated_by","public_record_user_id"],\
    "communications": ["appeal_id","application_id","asset_constraint_id","communication_type_id","creation_user_id","enforcement_id","id","last_updated_by","legal_agreement_id","legal_agreement_schedule_financial_id","officer_id","preapplication_id"],\
    "fee_payments": ["contact_id","creation_user_id","fee_id","id","last_updated_by","payment_method_id","receipting_officer_id"],\
    "appeal_decision": ["creation_user_id","id","last_updated_by"],\
    "appeal_status": ["creation_user_id","id","last_updated_by"],\
    "appeal_types": ["automated_stage_config_id","creation_user_id","id","last_updated_by"],\
    "breach_types": ["creation_user_id","id","last_updated_by"],\
    "committees": ["committee_agenda_layout_id","creation_user_id","id","last_updated_by","officer_id"],\
    "communication_templates": ["communication_type_id","creation_user_id","id","last_updated_by"],\
    "communication_types": ["creation_user_id","id","last_updated_by"],\
    "contact_types": ["creation_user_id","id","last_updated_by"],\
    "decision_levels": ["creation_user_id","id","last_updated_by"],\
    "decision_types": ["creation_user_id","id","last_updated_by"],\
    "document_types": ["creation_user_id","id","last_updated_by","validation_trigger_id"],\
    "fee_types": ["creation_user_id","id","last_updated_by"],\
    "ps_development_codes": ["creation_user_id","expiry_days","id","last_updated_by"],\
    "public_consultations": ["creation_user_id","document_id","id","last_updated_by","public_record_id"]}


booleanColumnsMap = {\
    "applications": ["a_charitable_use","advert_already_in_place","advertised_in_press","advert_projects_over_highway_public_highway","affordable_housing_component","agricultural_necessity","agricultural_tenancy_terminated","a_interior_works","alleged_subsidence_damage","alteration_of_existing_road_proposed","alteration_proposal","alterations_or_enlargement_to_roof","amended_application","a_new_build_floorspace_100m2","a_new_building_or_operations_proposed","a_new_build_permitted_floorspace_100m2","a_new_residential_floorspace","appeal_against_non_determination","applicant_has_permission_of_landowner_for_adverts","applicant_is_owner","applicant_owns_land_buildings","archeology_biodiversity_affected","a_total_demolition","at_risk_of_flooding","b_change_of_use_land_buildings_proposed","b_demolition_within_curtilage","b_exterior_works","b_floorspace_change_one_or_more_new_dwellings","b_new_non_residential_floorspace","b_one_or_more_new_dwellings","b_social_housing_relief","building_work","building_work_4sca","ceased","cess_pit_disposal","change_of_use","cil_ah_related","c_none_of_the_above","committee_overturn","consented_change_of_use","consultation_not_applicable","contamination_known","contamination_suspected","county_matters","c_partial_demolition","c_self_build_exemption_new_home","c_structure_object_within_curtilage","current_agricultural_tenancy","currently_vacant","date_planted_evidenced","demolition_of_building","demolition_proposal","designated_areas_aonb","designated_areas_conservation_area","designated_areas_green_belt","designated_areas_national_park","designated_areas_nnr","designated_areas_none_of_the_above","designated_areas_sac","designated_areas_spa_ramsar","designated_areas_sssi","designated_areas_world_heritage_site","designed_for_agriculture","details_on_plans","development_already_completed","development_already_started","development_plan_departure","dont_know","dont_know_5lbl","d_self_build_exemption_residential_annex_extension","d_stripping_of_walls_ceilings_finishes","dwelling_alteration_involved","ecclesiastical_grade_i","ecclesiastical_grade_ii","ecclesiastical_grade_ii_12lbc","eligibility","environmental_statement_es_attached","existing_building_works","existing_connection_planned","existing_council_relationship","existing_use","existing_use_works_activity_in_breach_of_a_condition","existing_watercourse","extension","extension_of_time_agreed","external_referral_required","flat_roof_installation","floor_area_465m2","from_nearest_non_farm_house_400m","from_roadway_25m","full_contact_not_known","gis_data_present","grade_i","grade_i_5lbl","grade_ii","grade_ii_12lbc","grade_ii_5lbl","hazardous_substances_consent_required","hazardous_substance_storage","height_of_proposed_development_na","icnirp_submitted","impact_on_existing_parking","insurance_claim","interceptor_ditch_and_sumps","interruption_in_breach_use_activity","in_time","lbc_details_on_plans","ldp_site","less_than_30_years_old","livestock_slurry_or_sewage_sludge_housing","local_consultation_carried_out","loss_of_trees_or_hedges","mains_disposal","mains_sewer","material_change_of_use","matters_to_be_determined_access","matters_to_be_determined_appearance","matters_to_be_determined_landscaping","matters_to_be_determined_layout","matters_to_be_determined_scale","matters_to_be_reserved_access","matters_to_be_reserved_appearance","matters_to_be_reserved_landscaping","matters_to_be_reserved_layout","matters_to_be_reserved_none","matters_to_be_reserved_scale","modification_or_discharge_requested_discharge","modification_or_discharge_requested_modify","new_altered_pedestrian_access","new_altered_vehicle_access","new_prows","new_public_roads","new_road_proposed","no_longer_required_for_agriculture","other_developments_90m_last_2_years","other_disposal","outline_draft_agreement_included","overturn_approval_to_refusal","overturn_refusal_to_approval","own_council_application","package_treatment_plant_disposal","partial_discharge","pitch_roof_installation","planning_performance_agreement_signed","pond_lake","pre_application_advice","previous_building","previous_cou_a1_a2_sg_to_a3","previous_cou_a1_a2_sg_to_d2","previous_cou_sg_to_c3","previous_excavations_deposits","proposal_requires_tree_hedge_pruning_removal","proposed_building_alteration","proposed_building_extension","proposed_building_new_building","proposed_new_building","provision_of_community_infrastructure","prows","public_open_space_loss_gain","recycling_storage_collection_arranged","redevelopment_rebuilding","regulation_4_application","related_to_reserved_matters_application","replacement_of_existing_apparatus","replant_required","residential_development_monitoring","result_of_enforcement","result_of_preapp","retained_excavated_material","retrospective_application","return_as_invalid","romp_application","row_diversions_extinguishments","s106_ah_related","section_73_application","septic_tank_disposal","site_publically_visible","soakaway","sole_a1_a2_sg_use_on_5_december_2013","sole_arcade_casino_use_on_19_march_2014","stand_alone_renewable_low_carbon_development","statutory_declaration_condition_applies","substitute_plans","supplementary_information_template_sit_submitted","sustainable_drainage","tan6_rural_enterprise_dwelling","temporary_consent","temporary_structures_equipment","tpo_title_known","trade_effluent_waste_involved","tree_health_and_safety","trees_additional_supporting_information","trees_hedges_on_relevant_adjacent_land","trees_hedges_present_on_site","trees_or_hedges_affected","trees_with_a_tree_protection_order_tpo","trees_within_a_conservation_area","trees_within_falling_distance_of_proposal","tree_works","twelve_month_resubmission","type_of_planning_agreement_s_106a","type_of_planning_agreement_s_106ba_affordable_housing","type_of_planning_agreement_s_299a_crown_land","use_vulnerable_to_contamination","valid_at_receipt","waste_management_proposal","waste_storage_collection_incorporated","watercourse_surface_water_groundwater_affected","will_proposal_increase_flood_risk_elsewhere","within_20m_of_watercourse","within_3km_of_aerodrome","work_already_started","work_completed","work_started"],\
    "contacts": ["agent","ceased","phone_book"],\
    "emails": ["ceased","show_in_message_center"],\
    "enforcements": ["advertised_in_press","ceased","county_matters","gis_data_present"],\
    "fees": ["apply_fee_type_1","apply_fee_type_2","apply_fee_type_3","apply_manual_fee","ceased","fee_exempt","half_fee_concession","multi_part_fee","overridden","paid","refunded"],\
    "public_comments": ["ceased"],\
    "communications": ["ceased","completed","draft","emailed","internal","printed"],\
    "fee_payments": ["ceased","paid","refund"],\
    "appeal_decision": ["against_lpa","ceased","enabled","for_lpa"],\
    "appeal_status": ["ceased","enabled","in_progress","is_default"],\
    "appeal_types": ["ceased","enabled"],\
    "breach_types": ["ceased","enabled"],\
    "committees": ["ceased"],\
    "communication_templates": ["ceased","enable_track_changes"],\
    "communication_types": ["ceased","decision_notice","enabled","eot_request","liability_demand_notice","neighbour_letter","report","validation"],\
    "contact_types": ["ceased","enabled","invoicee","is_default"],\
    "decision_levels": ["ceased","committee","enabled","is_default"],\
    "decision_types": ["approval_decision","cadw_external_referral","called_in","ceased","enabled","legal_dept_referral","pa_not_required","refusal_decision","show_on_portal","transfer","turned_away","withdrawal"],\
    "document_types": ["assessment_report","ceased","consultation_document","enabled","exclude_from_public_portal","is_default","press_notice","public_consultation","publicity_document","remove_from_portal_when_determined","show_consultation_stance","site_notice","spatial_analysis_results"],\
    "fee_types": ["appeal","application","ceased","enabled","enforcement","flat_fee","pre_application"],\
    "ps_development_codes": ["ceased","certificates_of_appropriate_alternative_development","certificates_of_lawful_development","certificates_of_lawfulness_proposed_works","enabled","exclude_from_stat_returns","exclude_from_stat_return_totals","major","minor","nma","notification","other","pa_for_pd","pa_for_pd_other"],\
    "public_consultations": ["bypass_redaction","ceased","display_comments","display_contact","display_file","is_public"]}

floatColumnsMap = {\
    "applications": ["acrylonitrile_tonnes_","ammonia_tonnes_","amount_of_open_space_gained","amount_of_open_space_lost","anaerobic_digestion","approximate_total_volume_m3","a_rear_projection_m","biofuels","biomass","b_ridge_height_m","bromine_tonnes_","brownfield_greenfield_greenfield_land","brownfield_greenfield_previously_developed_land","c1_flood_plain_risks_non_residential_units","c1_flood_plain_risks_residential_units","c2_flood_plain_risks_non_residential_units","c2_flood_plain_risks_residential_units","c_eaves_height_m","chlorine_tonnes_","combined_heat_and_power","commercial_and_industrial_throughput","construction_demolition_and_excavation_throughput","cumulative_cou_floorspace_m2","depth_height_of_excavation_landfilling_landraising","district_heating","ethylene_oxide_tonnes_","excavation_proposed_area_of_work","expected_community_infrastructure_levy_sum","expected_legal_agreement_sum","flat_roof_projection_m","floor_area","floorspace_proposed_for_cou_m2","floorspace_where_cou_proposed_m2","flour_tonnes_","fuel_cells","geothermal","gross_floor_space_m2","gross_floorspace_m2","gross_floorspace_m2_4acd","ground_water_air_heat_pumps","hazardous","hydrogen_cyanide_tonnes_","hydropower","length_of_hedgerow_removal","liquid_oxygen_tonnes_","liquid_petroleum_gas_tonnes_","market_housing_existing_gross_int_floorspace","market_housing_gross_int_floorspace_lost","market_housing_total_gross_floorspace_proposed","maximum_height_m","municipal_throughput","number_of_holding","other_renewable_low_carbon_energy_capacity","other_tonnes_","phosgene_tonnes_","pitched_roof_projection_m","previous_excavations_deposits_area","previous_total_cou_floorspace_m2","previous_total_cou_floorspace_m2_4acd","previous_total_cou_floorspace_m2_4sca","proposed_area_of_unit","proposed_cou_floorspace_m2","proposed_road_dimensions_length","proposed_road_dimensions_width","proposed_total_cou_floorspace_m2","proposed_total_cou_floorspace_m2_4sca","quantity_m3","refined_white_sugar_tonnes_","site_area_gis","site_area_hectares","site_area_proposed_for_cou_ha","size_of_holding","social_housing_existing_gross_int_floorspace","social_housing_gross_int_floorspace_lost","social_housing_total_gross_floorspace_proposed","solar","sulphur_dioxide_tonnes_","surface_area_ha","surface_site_area_ha","total_cou_floorspace_m2","total_fee","total_non_residential_existing_gross_int_floorspace","total_non_residential_gross_int_floorspace_lost","total_non_residential_total_gross_floorspace_proposed","total_residential_existing_gross_int_floorspace","total_residential_gross_int_floorspace_lost","total_residential_total_gross_floorspace_proposed","waste_heat_energy","wind"],\
    "contacts": [],\
    "emails": [],\
    "enforcements": [],\
    "fees": ["fee","manual_fee","proposed_floor_space","proposed_site_area"],\
    "public_comments": [],\
    "communications": [],\
    "fee_payments": ["amount_paid"],\
    "appeal_decision": [],\
    "appeal_status": [],\
    "appeal_types": [],\
    "breach_types": [],\
    "committees": [],\
    "communication_templates": [],\
    "communication_types": [],\
    "contact_types": [],\
    "decision_levels": [],\
    "decision_types": [],\
    "document_types": [],\
    "fee_types": ["fee"],\
    "ps_development_codes": [],\
    "public_consultations": []}

bigintColumnsMap = {\
    "applications": ["site_address_x","site_address_y","tree_location_x","tree_location_y"],\
    "contacts": [],\
    "emails": ["last_updated", "submit_date", "ceased_date"],\
    "enforcements": ["complaint_location_x","complaint_location_y"],\
    "fees": [],\
    "public_comments": [],\
    "communications": [],\
    "fee_payments": [],\
    "appeal_decision": [],\
    "appeal_status": [],\
    "appeal_types": [],\
    "breach_types": [],\
    "committees": [],\
    "communication_templates": [],\
    "communication_types": [],\
    "contact_types": [],\
    "decision_levels": [],\
    "decision_types": [],\
    "document_types": [],\
    "fee_types": [],\
    "ps_development_codes": [],\
    "public_consultations": []}

doubleColumnsMap = {\
    "applications": ["affordable_housing_balancing_sum","height_of_proposed_development","proposed_building_dimensions_breadth","proposed_building_dimensions_eaves","proposed_building_dimensions_length","proposed_building_dimensions_ridge","proposed_building_distance_from_proposal","proposed_building_overall_ground_area","proposed_fish_tank_cage_depth","proposed_fish_tank_cage_height","proposed_fish_tank_cage_length","proposed_fish_tank_cage_width"],\
    "contacts": [],\
    "emails": [],\
    "enforcements": [],\
    "fees": [],\
    "public_comments": [],\
    "communications": [],\
    "fee_payments": [],\
    "appeal_decision": [],\
    "appeal_status": [],\
    "appeal_types": [],\
    "breach_types": [],\
    "committees": [],\
    "communication_templates": [],\
    "communication_types": [],\
    "contact_types": [],\
    "decision_levels": [],\
    "decision_types": [],\
    "document_types": [],\
    "fee_types": [],\
    "ps_development_codes": [],\
    "public_consultations": []}

dateColumnsMap = {\
    "applications": [],\
    "contacts": [],\
    "emails": [],\
    "enforcements": [],\
    "fees": [],\
    "public_comments": [],\
    "communications": [],\
    "fee_payments": [],\
    "appeal_decision": [],\
    "appeal_status": [],\
    "appeal_types": [],\
    "breach_types": [],\
    "committees": [],\
    "communication_templates": [],\
    "communication_types": [],\
    "contact_types": [],\
    "decision_levels": [],\
    "decision_types": [],\
    "document_types": [],\
    "fee_types": [],\
    "ps_development_codes": [],\
    "public_consultations": []}

def castTimestampColumns(columnMap,tableName,df):
    for colName in columnMap[tableName]:
        print ("converting " + colName + " to timestamp")
        df = df.withColumn(colName ,col(colName).cast(TimestampType()))
    return df

def castIntegerColumns(columnMap,tableName,df):
    for colName in columnMap[tableName]:
        print ("converting " + colName + " to integer")
        df = df.withColumn(colName ,col(colName).cast(IntegerType()))
    return df

def castBooleanColumns(columnMap,tableName,df):
    for colName in columnMap[tableName]:
        print ("converting " + colName + " to boolean")
        df = df.withColumn(colName ,col(colName).cast(BooleanType()))
    return df

def castFloatColumns(columnMap,tableName,df):
    for colName in columnMap[tableName]:
        print ("converting " + colName + " to float")
        df = df.withColumn(colName ,col(colName).cast(FloatType()))
    return df

def castBigintColumns(columnMap,tableName,df):
    for colName in columnMap[tableName]:
        print ("converting " + colName + " to long")
        df = df.withColumn(colName ,col(colName).cast(LongType()))
    return df

def castDoubleColumns(columnMap,tableName,df):
    for colName in columnMap[tableName]:
        print ("converting " + colName + " to double")
        df = df.withColumn(colName ,col(colName).cast(DoubleType()))
    return df

def castDateColumns(columnMap,tableName,df):
    for colName in columnMap[tableName]:
        print ("converting " + colName + " to date")
        df = df.withColumn(colName ,col(colName).cast(DateType()))
    return df

# source_df = castTimestampColumns(columnMap=timestampColumnsMap, tableName=nameOfTableToRecast, df=source_df)
# source_df = castIntegerColumns(columnMap=integerColumnsMap, tableName=nameOfTableToRecast, df=source_df)
# source_df = castBooleanColumns(columnMap=booleanColumnsMap, tableName=nameOfTableToRecast, df=source_df)
# source_df = castFloatColumns(columnMap=floatColumnsMap, tableName=nameOfTableToRecast, df=source_df)
# source_df = castBigintColumns(columnMap=bigintColumnsMap, tableName=nameOfTableToRecast, df=source_df)
# source_df = castDoubleColumns(columnMap=doubleColumnsMap, tableName=nameOfTableToRecast, df=source_df)
# source_df = castDateColumns(columnMap=dateColumnsMap, tableName=nameOfTableToRecast, df=source_df)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
for nameOfTableToRecast in tableList:
    
#   load data
    source_ddf = glueContext.create_dynamic_frame.from_catalog(
        name_space=databaseName,
        table_name=nameOfTableToRecast
    )

    source_df = source_ddf.toDF()
    
    print((source_df.count()))


#     source_df = get_latest_partitions(source_df)

#   remove json col
#     source_df = source_df.drop("json")
#     source_df = source_df.drop(nameOfTableToRecast)

#   recast
    source_df = castTimestampColumns(columnMap=timestampColumnsMap, tableName=nameOfTableToRecast, df=source_df)
    source_df = castIntegerColumns(columnMap=integerColumnsMap, tableName=nameOfTableToRecast, df=source_df)
    source_df = castBooleanColumns(columnMap=booleanColumnsMap, tableName=nameOfTableToRecast, df=source_df)
    source_df = castFloatColumns(columnMap=floatColumnsMap, tableName=nameOfTableToRecast, df=source_df)
    source_df = castBigintColumns(columnMap=bigintColumnsMap, tableName=nameOfTableToRecast, df=source_df)
    source_df = castDoubleColumns(columnMap=doubleColumnsMap, tableName=nameOfTableToRecast, df=source_df)
    source_df = castDateColumns(columnMap=dateColumnsMap, tableName=nameOfTableToRecast, df=source_df)
    source_df.printSchema()
    print((source_df.count()))

## WRITE TO S3

    resultDataFrame = DynamicFrame.fromDF(source_df, glueContext, "resultDataFrame")
    target_destination = f"s3://dataplatform-stg-refined-zone/TEMP/{nameOfTableToRecast}"
    parquetData = glueContext.write_dynamic_frame.from_options(
        frame=resultDataFrame,
        connection_type="s3",
        format="parquet",
        connection_options={"path": target_destination, "partitionKeys": PARTITION_KEYS},
        transformation_ctx="parquetData")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 72581
# converting advertisement_from to timestamp
# converting advertisement_to to timestamp
# converting agricultural_holding_involved_owner_notified to timestamp
# converting agricultural_holding_involved_signed_on to timestamp
# converting application_declaration_signed_on to timestamp
# converting beneficial_occupation_date to timestamp
# converting brought_into_use_date_20_march_2013_or_later to timestamp
# converting ceased_date to timestamp
# converting certificate_a_signed_on to timestamp
# converting certificate_b_owner_notified to timestamp
# converting certificate_b_signed_on to timestamp
# converting certificate_c_owner_notified to timestamp
# converting certificate_c_publicity_date to timestamp
# converting certificate_c_signed_on to timestamp
# converting certificate_d_publicity_date to timestamp
# converting certificate_d_signed_on to timestamp
# ...
